# %%
import pandas as pd

pd.read_csv("/scratch/harsha.vasamsetti/Drug_Safety_Labels_Output.csv")
# Out:
#                                     Drug  Application Number  \
# 0   Drug Safety-related Labeling Changes                 NaN
# 1   Drug Safety-related Labeling Changes                 NaN
# 2   Drug Safety-related Labeling Changes                 NaN
# 3   Drug Safety-related Labeling Changes                 NaN
# 4   Drug Safety-related Labeling Changes                 NaN
# 5   Drug Safety-related Labeling Changes                 NaN
# 6   Drug Safety-related Labeling Changes                 NaN
# 7   Drug Safety-related Labeling Changes                 NaN
# 8   Drug Safety-related Labeling Changes                 NaN
# 9   Drug Safety-related Labeling Changes                 NaN
# 10  Drug Safety-related Labeling Changes                 NaN
# 11  Drug Safety-related Labeling Changes                 NaN
# 12  Drug Safety-related Labeling Changes                 NaN
# 13  Drug Safety-related Labeling Changes                 NaN
# 14  Drug Safety-related Labeling Changes                 NaN
# 15  Drug Safety-related Labeling Changes                 NaN
# 16  Drug Safety-related Labeling Changes                 NaN
# 17  Drug Safety-related Labeling Changes                 NaN
# 18  Drug Safety-related Labeling Changes                 NaN
# 19  Drug Safety-related Labeling Changes                 NaN
# 20  Drug Safety-related Labeling Changes                 NaN
# 21  Drug Safety-related Labeling Changes                 NaN
# 22  Drug Safety-related Labeling Changes                 NaN
# 23  Drug Safety-related Labeling Changes                 NaN
# 24  Drug Safety-related Labeling Changes                 NaN
# 25  Drug Safety-related Labeling Changes                 NaN
# 26  Drug Safety-related Labeling Changes                 NaN
# 27  Drug Safety-related Labeling Changes                 NaN
# 28  Drug Safety-related Labeling Changes                 NaN
# 29  Drug Safety-related Labeling Changes                 NaN
# 30  Drug Safety-related Labeling Changes                 NaN
# 31  Drug Safety-related Labeling Changes                 NaN
# 32  Drug Safety-related Labeling Changes                 NaN
# 33  Drug Safety-related Labeling Changes                 NaN
# 34  Drug Safety-related Labeling Changes                 NaN
# 35  Drug Safety-related Labeling Changes                 NaN
# 36  Drug Safety-related Labeling Changes                 NaN
# 37  Drug Safety-related Labeling Changes                 NaN
# 38  Drug Safety-related Labeling Changes                 NaN
# 39  Drug Safety-related Labeling Changes                 NaN
# 40  Drug Safety-related Labeling Changes                 NaN
# 41  Drug Safety-related Labeling Changes                 NaN
# 42  Drug Safety-related Labeling Changes                 NaN
# 43  Drug Safety-related Labeling Changes                 NaN
# 44  Drug Safety-related Labeling Changes                 NaN
# 45  Drug Safety-related Labeling Changes                 NaN
# 46  Drug Safety-related Labeling Changes                 NaN
#
#                     Date Boxed Warning Contraindications  \
# 0   11/30/2022(SUPPL-48)           NaN               NaN
# 1   02/05/2020(SUPPL-44)           NaN               NaN
# 2   02/05/2020(SUPPL-45)           NaN               NaN
# 3   08/07/2019(SUPPL-43)           NaN               NaN
# 4   02/23/2017(SUPPL-42)           NaN               NaN
# 5   08/18/2016(SUPPL-41)           NaN               NaN
# 6   01/15/2016(SUPPL-40)           NaN               NaN
# 7   02/05/2020(SUPPL-35)           NaN               NaN
# 8   02/05/2020(SUPPL-36)           NaN               NaN
# 9   08/07/2019(SUPPL-34)           NaN               NaN
# 10  02/23/2017(SUPPL-33)           NaN               NaN
# 11  08/18/2016(SUPPL-32)           NaN               NaN
# 12  01/15/2016(SUPPL-31)           NaN               NaN
# 13  02/05/2020(SUPPL-27)           NaN               NaN
# 14  02/05/2020(SUPPL-28)           NaN               NaN
# 15  08/07/2019(SUPPL-26)           NaN               NaN
# 16  02/23/2017(SUPPL-25)           NaN               NaN
# 17  08/18/2016(SUPPL-24)           NaN               NaN
# 18  01/15/2016(SUPPL-23)           NaN               NaN
# 19  02/05/2020(SUPPL-29)           NaN               NaN
# 20  02/05/2020(SUPPL-30)           NaN               NaN
# 21  08/07/2019(SUPPL-28)           NaN               NaN
# 22  02/23/2017(SUPPL-27)           NaN               NaN
# 23  08/18/2016(SUPPL-26)           NaN               NaN
# 24  01/15/2016(SUPPL-25)           NaN               NaN
# 25  02/05/2020(SUPPL-13)           NaN               NaN
# 26  07/27/2017(SUPPL-10)           NaN               NaN
# 27  02/23/2017(SUPPL-11)           NaN               NaN
# 28   08/18/2016(SUPPL-9)           NaN               NaN
# 29   01/15/2016(SUPPL-8)           NaN               NaN
# 30   11/30/2022(SUPPL-6)           NaN               NaN
# 31   12/19/2020(SUPPL-3)           NaN               NaN
# 32   02/05/2020(SUPPL-2)           NaN               NaN
# 33   02/05/2020(SUPPL-4)           NaN               NaN
# 34  08/25/2020(SUPPL-47)           NaN                 x
# 35  12/06/2019(SUPPL-46)           NaN               NaN
# 36  08/16/2018(SUPPL-45)           NaN               NaN
# 37   10/04/2023(SUPPL-7)           NaN               NaN
# 38  08/16/2023(SUPPL-11)           NaN               NaN
# 39   06/14/2023(SUPPL-9)           NaN               NaN
# 40   07/29/2022(SUPPL-6)           NaN               NaN
# 41  07/18/2023(SUPPL-24)           NaN               NaN
# 42  11/07/2019(SUPPL-13)             x                 x
# 43  05/02/2018(SUPPL-11)           NaN               NaN
# 44  07/18/2023(SUPPL-11)           NaN               NaN
# 45  10/07/2019(SUPPL-18)           NaN               NaN
# 46  12/16/2016(SUPPL-15)             x                 x
#
#    Warnings and Precautions Adverse Reactions Drug Interactions  \
# 0                       NaN                 x               NaN
# 1                       NaN                 x               NaN
# 2                       NaN                 x               NaN
# 3                       NaN               NaN               NaN
# 4                         x                 x               NaN
# 5                         x                 x               NaN
# 6                       NaN                 x               NaN
# 7                       NaN                 x               NaN
# 8                       NaN                 x               NaN
# 9                       NaN               NaN               NaN
# 10                        x                 x               NaN
# 11                        x                 x               NaN
# 12                      NaN                 x               NaN
# 13                      NaN                 x               NaN
# 14                      NaN                 x               NaN
# 15                      NaN               NaN               NaN
# 16                        x                 x               NaN
# 17                        x                 x               NaN
# 18                      NaN                 x               NaN
# 19                      NaN                 x               NaN
# 20                      NaN                 x               NaN
# 21                      NaN               NaN               NaN
# 22                        x                 x               NaN
# 23                        x                 x               NaN
# 24                      NaN                 x               NaN
# 25                      NaN                 x               NaN
# 26                        x                 x               NaN
# 27                        x                 x               NaN
# 28                        x                 x               NaN
# 29                      NaN                 x               NaN
# 30                      NaN                 x               NaN
# 31                      NaN                 x               NaN
# 32                      NaN                 x               NaN
# 33                      NaN                 x               NaN
# 34                        x               NaN               NaN
# 35                      NaN               NaN               NaN
# 36                        x                 x                 x
# 37                        x                 x                 x
# 38                        x                 x               NaN
# 39                        x                 x               NaN
# 40                        x                 x               NaN
# 41                        x                 x               NaN
# 42                        x                 x                 x
# 43                        x               NaN               NaN
# 44                        x                 x               NaN
# 45                        x               NaN                 x
# 46                        x                 x                 x
#
#    Use in Specific Populations PCI/PI/MG
# 0                            x       NaN
# 1                          NaN       NaN
# 2                          NaN       NaN
# 3                            x       NaN
# 4                          NaN       NaN
# 5                          NaN         x
# 6                          NaN       NaN
# 7                          NaN       NaN
# 8                          NaN       NaN
# 9                            x       NaN
# 10                         NaN       NaN
# 11                         NaN         x
# 12                         NaN       NaN
# 13                         NaN       NaN
# 14                         NaN       NaN
# 15                           x       NaN
# 16                         NaN       NaN
# 17                         NaN         x
# 18                         NaN       NaN
# 19                         NaN       NaN
# 20                         NaN       NaN
# 21                           x       NaN
# 22                         NaN       NaN
# 23                         NaN         x
# 24                         NaN       NaN
# 25                         NaN       NaN
# 26                         NaN       NaN
# 27                         NaN       NaN
# 28                         NaN         x
# 29                         NaN       NaN
# 30                           x       NaN
# 31                         NaN         x
# 32                         NaN       NaN
# 33                         NaN       NaN
# 34                           x         x
# 35                           x       NaN
# 36                           x         x
# 37                         NaN       NaN
# 38                         NaN         x
# 39                           x         x
# 40                           x         x
# 41                         NaN         x
# 42                           x         x
# 43                         NaN         x
# 44                         NaN         x
# 45                         NaN         x
# 46                           x         x

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import logging
import random
import time
from tqdm import tqdm
import os

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Load the input CSV file
input_file_path = '/scratch/harsha.vasamsetti/Drug Safety-related Labeling Changes (SrLC).csv'
drug_data = pd.read_csv(input_file_path)

# Define columns for the output CSV
columns = [
    'Drug', 'Application Number', 'Boxed Warning', 'Contraindications',
    'Warnings and Precautions', 'Adverse Reactions', 'Drug Interactions',
    'Use in Specific Populations', 'PCI/PI/MG'
]

# List of User-Agent strings
user_agents = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:89.0) Gecko/20100101 Firefox/89.0',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'
]

# Set up a requests Session
session = requests.Session()

# Common headers for a real browser
base_headers = {
    'User-Agent': random.choice(user_agents),
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Referer': 'https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-User': '?1',
    'Host': 'www.accessdata.fda.gov',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache'
}

def extract_sections(url):
    section_data = {
        'Boxed Warning': '',
        'Contraindications': '',
        'Warnings and Precautions': '',
        'Adverse Reactions': '',
        'Drug Interactions': '',
        'Use in Specific Populations': '',
        'PCI/PI/MG': ''
    }
    try:
        # Randomize the User-Agent for each request
        headers = base_headers.copy()
        headers['User-Agent'] = random.choice(user_agents)
        
        # Request the detail page
        response = session.get(url, headers=headers, timeout=10, allow_redirects=True)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Extract Drug Name and Application Number
            h3_tags = soup.find_all('h3')
            for h3 in h3_tags:
                if 'small' in str(h3):
                    drug_app_info = h3.get_text(strip=True)
                    drug_name = drug_app_info.split(' (')[0]
                    app_number = drug_app_info.split('(NDA-')[1].split(')')[0]
                    section_data['Drug'] = drug_name
                    section_data['Application Number'] = app_number
                    break
            
            # Check for sections in h2, h3, h4
            for header in soup.find_all(['h2', 'h3', 'h4']):
                header_text = header.get_text(strip=True).lower()
                if 'boxed warning' in header_text:
                    section_data['Boxed Warning'] = 'x'
                elif 'contraindications' in header_text:
                    section_data['Contraindications'] = 'x'
                elif 'warnings and precautions' in header_text:
                    section_data['Warnings and Precautions'] = 'x'
                elif 'adverse reactions' in header_text:
                    section_data['Adverse Reactions'] = 'x'
                elif 'drug interactions' in header_text:
                    section_data['Drug Interactions'] = 'x'
                elif 'use in specific populations' in header_text:
                    section_data['Use in Specific Populations'] = 'x'
                elif 'pci' in header_text or 'patient counseling information' in header_text:
                    section_data['PCI/PI/MG'] = 'x'
        else:
            logging.error(f"Failed to retrieve URL {url}: Status code {response.status_code}")
    except Exception as e:
        logging.error(f"Error processing URL {url}: {e}")
    
    return section_data

# Define the output file path
output_file_path = 'Drug_Safety_Labels_Output.csv'

# Check if the file exists; if not, write the header
if not os.path.exists(output_file_path):
    pd.DataFrame(columns=columns).to_csv(output_file_path, index=False)

# Process each drug in the input file
for index, row in tqdm(drug_data.iterrows(), total=len(drug_data)):
    drug = row.get('Drug', '')
    application_number = row.get('Application Number', '')
    link = row.get('Link', '')

    if pd.notna(link) and isinstance(link, str) and link.strip():
        logging.info(f"Processing {drug} ({application_number}) => {link}")
        sections = extract_sections(link)
        row_data = {
            'Drug': sections.get('Drug', ''),
            'Application Number': sections.get('Application Number', ''),
            **sections
        }
        # Create a DataFrame for the single row
        df = pd.DataFrame([row_data], columns=columns)
        # Append the DataFrame to the CSV file without the header
        df.to_csv(output_file_path, mode='a', header=False, index=False)
        # Random delay (2-5 seconds) to reduce chances of being blocked
        time.sleep(random.uniform(2, 5))

logging.info(f"Data extraction complete. Output saved to {output_file_path}")
# Out:
#   0%|          | 0/2993 [00:00<?, ?it/s]2025-01-18 17:42:10,275 - INFO - Processing  (21436) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=38
#   0%|          | 1/2993 [00:04<3:56:39,  4.75s/it]2025-01-18 17:42:15,022 - INFO - Processing  (21713) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=39
#   0%|          | 2/2993 [00:08<3:25:43,  4.13s/it]2025-01-18 17:42:18,716 - INFO - Processing  (21729) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=40
#   0%|          | 3/2993 [00:11<2:57:24,  3.56s/it]2025-01-18 17:42:21,602 - INFO - Processing  (21866) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=41
#   0%|          | 4/2993 [00:15<3:05:16,  3.72s/it]2025-01-18 17:42:25,565 - INFO - Processing  (202971) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=24
#   0%|          | 5/2993 [00:18<2:51:19,  3.44s/it]2025-01-18 17:42:28,510 - INFO - Processing  (207202) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2193
#   0%|          | 6/2993 [00:21<2:49:10,  3.40s/it]2025-01-18 17:42:31,826 - INFO - Processing  (21660) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1655
#   0%|          | 7/2993 [00:26<3:06:46,  3.75s/it]2025-01-18 17:42:36,310 - INFO - Processing  (761118) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2650
# 2025-01-18 17:42:36,940 - ERROR - Error processing URL https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2650: list index out of range
#   0%|          | 8/2993 [00:30<3:20:50,  4.04s/it]2025-01-18 17:42:40,954 - INFO - Processing  (21951) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1555
#   0%|          | 9/2993 [00:36<3:42:14,  4.47s/it]2025-01-18 17:42:46,373 - INFO - Processing  (211913) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2819
#   0%|          | 10/2993 [00:41<3:55:33,  4.74s/it]2025-01-18 17:42:51,714 - INFO - Processing  (22510) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=768
#   0%|          | 11/2993 [00:45<3:40:11,  4.43s/it]2025-01-18 17:42:55,446 - INFO - Processing  (21538) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=592
# 2025-01-18 17:42:56,045 - ERROR - Error processing URL https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=592: list index out of range
#   0%|          | 12/2993 [00:50<3:49:52,  4.63s/it]2025-01-18 17:43:00,523 - INFO - Processing  (212320) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2585
#   0%|          | 13/2993 [00:53<3:31:35,  4.26s/it]2025-01-18 17:43:03,940 - INFO - Processing  (19885) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=842
#   0%|          | 14/2993 [00:56<3:11:50,  3.86s/it]2025-01-18 17:43:06,887 - INFO - Processing  (20125) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1037
#   1%|          | 15/2993 [00:59<2:54:45,  3.52s/it]2025-01-18 17:43:09,614 - INFO - Processing  (20184) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1293
#   1%|          | 16/2993 [01:04<3:14:16,  3.92s/it]2025-01-18 17:43:14,446 - INFO - Processing  (21539) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=315
#   1%|          | 16/2993 [01:05<3:22:58,  4.09s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 133
#     131         df.to_csv(output_file_path, mode='a', header=False, index=False)
#     132         # Random delay (2-5 seconds) to reduce chances of being blocked
# --> 133         time.sleep(random.uniform(2, 5))
#     135 logging.info(f"Data extraction complete. Output saved to {output_file_path}")
#
# KeyboardInterrupt:

# %%
Drug,                Application Number,  Date,                   Boxed Warning,  Contraindications,  Warnings and Precautions,  Adverse Reactions,  Drug Interactions,  Use in Specific Populations,  PCI/PI/MG
ABILIFY(NDA-021436), 021436,              11/30/2022,             ,                 ,                       ,                     x,                    ,                          x,                     ,
ABILIFY(NDA-021436), 021436,              02/05/2020,             ,                 ,                       ,                     x,                    ,                           ,                     ,
ABILIFY(NDA-021436), 021436,              02/05/2020,             ,                 ,                       ,                     x,                    ,                           ,                     ,
ABILIFY(NDA-021436), 021436,              08/07/2019,             ,                 ,                       ,                      ,                    ,                          x,                     ,
ABILIFY(NDA-021436), 021436,              02/23/2017,             ,                 ,                      x,                     x,                    ,                           ,                     , 
ABILIFY(NDA-021436), 021436,              08/18/2016,             ,                 ,                      x,                     x,                    ,                           ,                    x,
ABILIFY(NDA-021436), 021436,              01/15/2016,             ,                 ,                       ,                     x,                    ,                           ,                     ,
ABILIFY(NDA-021713), 021713,              02/05/2020              ,                 ,                       ,                     x,                    ,                           ,                     ,
ABILIFY(NDA-021713), 021713,              02/05/2020              ,                 ,                       ,                     x,                    ,                           ,                     ,
ABILIFY(NDA-021713), 021713,              08/07/2019              ,                 ,                       ,                      ,                    ,                          x,                     ,
ABILIFY(NDA-021713), 021713,              02/23/2017              ,                 ,                      x,                     x,                    ,                           ,                     ,
ABILIFY(NDA-021713), 021713,              08/18/2016              ,                 ,                      x,                     x,                    ,                           ,                    x,
ABILIFY(NDA-021713), 021713,              01/15/2016              ,                 ,                       ,                     x,                    ,                           ,                     ,

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import logging
import random
import time
from tqdm import tqdm
import os
import re

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Load the input CSV file
input_file_path = '/scratch/harsha.vasamsetti/Drug Safety-related Labeling Changes (SrLC).csv'
drug_data = pd.read_csv(input_file_path)

# Define columns for the output CSV
columns = [
    'Drug', 'Application Number', 'Date', 'Boxed Warning', 'Contraindications',
    'Warnings and Precautions', 'Adverse Reactions', 'Drug Interactions',
    'Use in Specific Populations', 'PCI/PI/MG'
]

# List of User-Agent strings
user_agents = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:89.0) Gecko/20100101 Firefox/89.0',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'
]

# Set up a requests Session
session = requests.Session()

# Common headers for a real browser
base_headers = {
    'User-Agent': random.choice(user_agents),
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Referer': 'https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-User': '?1',
    'Host': 'www.accessdata.fda.gov',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache'
}

def extract_sections(url):
    updates = []
    try:
        headers = base_headers.copy()
        headers['User-Agent'] = random.choice(user_agents)
        response = session.get(url, headers=headers, timeout=10, allow_redirects=True)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            # Find the h3 tag containing the drug name and application number
            h3_tags = soup.find_all('h3')
            drug_name = ''
            app_number = ''
            for h3 in h3_tags:
                if 'NDA-' in h3.get_text():
                    drug_app_info = h3.get_text(strip=True)
                    drug_name = drug_app_info.split(' (')[0].strip()
                    app_number_match = re.search(r'NDA-(\d+)', drug_app_info)
                    if app_number_match:
                        app_number = app_number_match.group(1)
                    break
            # Find all update headers
            update_headers = soup.find_all('h3', class_='background_text accordion-header ui-accordion-header ui-helper-reset ui-state-default ui-accordion-icons ui-corner-all')
            for header in update_headers:
                date_str = header.find(text=True, recursive=False).strip()
                content_div = header.find_next('div', class_='ui-accordion-content ui-helper-reset ui-widget-content ui-corner-bottom')
                if content_div:
                    sections = {
                        'Boxed Warning': '',
                        'Contraindications': '',
                        'Warnings and Precautions': '',
                        'Adverse Reactions': '',
                        'Drug Interactions': '',
                        'Use in Specific Populations': '',
                        'PCI/PI/MG': ''
                    }
                    for h4 in content_div.find_all('h4'):
                        header_text = h4.get_text(strip=True).lower()
                        if 'boxed warning' in header_text:
                            sections['Boxed Warning'] = 'x'
                        elif 'contraindications' in header_text:
                            sections['Contraindications'] = 'x'
                        elif 'warnings and precautions' in header_text:
                            sections['Warnings and Precautions'] = 'x'
                        elif 'adverse reactions' in header_text:
                            sections['Adverse Reactions'] = 'x'
                        elif 'drug interactions' in header_text:
                            sections['Drug Interactions'] = 'x'
                        elif 'use in specific populations' in header_text:
                            sections['Use in Specific Populations'] = 'x'
                        elif 'pci' in header_text or 'patient counseling information' in header_text:
                            sections['PCI/PI/MG'] = 'x'
                    update_data = {
                        'Drug': drug_name,
                        'Application Number': app_number,
                        'Date': date_str,
                        **sections
                    }
                    updates.append(update_data)
        else:
            logging.error(f"Failed to retrieve URL {url}: Status code {response.status_code}")
    except Exception as e:
        logging.error(f"Error processing URL {url}: {e}")
    return updates

# Define the output file path
output_file_path = 'Drug_Safety_Labels_Output.csv'

# Check if the file exists; if not, write the header
if not os.path.exists(output_file_path):
    pd.DataFrame(columns=columns).to_csv(output_file_path, index=False, encoding='utf-8')

# Process each drug in the input file
for index, row in tqdm(drug_data.iterrows(), total=len(drug_data)):
    drug = row.get('Drug', '')
    application_number = row.get('Application Number', '')
    link = row.get('Link', '')

    if pd.notna(link) and isinstance(link, str) and link.strip():
        logging.info(f"Processing {drug} ({application_number}) => {link}")
        updates = extract_sections(link)
        for update in updates:
            df = pd.DataFrame([update], columns=columns)
            df.to_csv(output_file_path, mode='a', header=False, index=False, encoding='utf-8')
        time.sleep(random.uniform(2, 5))

logging.info(f"Data extraction complete. Output saved to {output_file_path}")
# Out:
#   0%|          | 0/2993 [00:00<?, ?it/s]2025-01-18 18:00:36,547 - INFO - Processing  (21436) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=38
# /tmp/ipykernel_40608/1262514078.py:76: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   date_str = header.find(text=True, recursive=False).strip()
#   0%|          | 1/2993 [00:04<3:53:49,  4.69s/it]2025-01-18 18:00:41,236 - INFO - Processing  (21713) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=39
#   0%|          | 2/2993 [00:09<3:44:43,  4.51s/it]2025-01-18 18:00:45,619 - INFO - Processing  (21729) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=40
#   0%|          | 3/2993 [00:14<3:57:05,  4.76s/it]2025-01-18 18:00:50,674 - INFO - Processing  (21866) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=41
#   0%|          | 4/2993 [00:19<4:08:01,  4.98s/it]2025-01-18 18:00:55,991 - INFO - Processing  (202971) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=24
#   0%|          | 5/2993 [00:24<4:02:21,  4.87s/it]2025-01-18 18:01:00,659 - INFO - Processing  (207202) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2193
#   0%|          | 6/2993 [00:29<4:05:08,  4.92s/it]2025-01-18 18:01:05,695 - INFO - Processing  (21660) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1655
#   0%|          | 7/2993 [00:33<3:57:09,  4.77s/it]2025-01-18 18:01:10,134 - INFO - Processing  (761118) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2650
#   0%|          | 8/2993 [00:38<3:54:20,  4.71s/it]2025-01-18 18:01:14,725 - INFO - Processing  (21951) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1555
#   0%|          | 9/2993 [00:43<4:07:05,  4.97s/it]2025-01-18 18:01:20,261 - INFO - Processing  (211913) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2819
#   0%|          | 10/2993 [00:47<3:49:16,  4.61s/it]2025-01-18 18:01:24,074 - INFO - Processing  (22510) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=768
#   0%|          | 11/2993 [00:52<3:47:18,  4.57s/it]2025-01-18 18:01:28,562 - INFO - Processing  (21538) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=592
#   0%|          | 12/2993 [00:55<3:35:04,  4.33s/it]2025-01-18 18:01:32,331 - INFO - Processing  (212320) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2585
#   0%|          | 13/2993 [01:00<3:43:39,  4.50s/it]2025-01-18 18:01:37,235 - INFO - Processing  (19885) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=842
#   0%|          | 14/2993 [01:04<3:38:14,  4.40s/it]2025-01-18 18:01:41,382 - INFO - Processing  (20125) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1037
#   1%|          | 15/2993 [01:08<3:24:54,  4.13s/it]2025-01-18 18:01:44,891 - INFO - Processing  (20184) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1293
#   1%|          | 16/2993 [01:11<3:10:16,  3.83s/it]2025-01-18 18:01:48,044 - INFO - Processing  (21539) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=315
#   1%|          | 17/2993 [01:14<2:53:46,  3.50s/it]2025-01-18 18:01:50,777 - INFO - Processing  (204767) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=
=> https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2621
#   9%|▉         | 284/2993 [19:52<2:50:58,  3.79s/it]2025-01-18 18:20:28,998 - INFO - Processing  (212018) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2612
#  10%|▉         | 285/2993 [19:56<2:50:08,  3.77s/it]2025-01-18 18:20:32,729 - INFO - Processing  (21911) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2124
#  10%|▉         | 286/2993 [20:00<3:01:09,  4.02s/it]2025-01-18 18:20:37,317 - INFO - Processing  (201367) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2125
#  10%|▉         | 287/2993 [20:04<2:52:41,  3.83s/it]2025-01-18 18:20:40,712 - INFO - Processing  (210134) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2349
#  10%|▉         | 288/2993 [20:08<3:04:19,  4.09s/it]2025-01-18 18:20:45,405 - INFO - Processing  (21797) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1804
#  10%|▉         | 289/2993 [20:12<3:00:54,  4.01s/it]2025-01-18 18:20:49,246 - INFO - Processing  (21798) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1805
#  10%|▉         | 290/2993 [20:17<3:17:03,  4.37s/it]2025-01-18 18:20:54,460 - INFO - Processing  (205692) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1670
#  10%|▉         | 291/2993 [20:23<3:32:37,  4.72s/it]2025-01-18 18:20:59,992 - INFO - Processing  (761049) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1313
#  10%|▉         | 292/2993 [20:26<3:13:13,  4.29s/it]2025-01-18 18:21:03,283 - INFO - Processing  (208610) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1702
#  10%|▉         | 293/2993 [20:30<3:04:09,  4.09s/it]2025-01-18 18:21:06,909 - INFO - Processing  (208611) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1708
#  10%|▉         | 294/2993 [20:35<3:12:19,  4.28s/it]2025-01-18 18:21:11,610 - INFO - Processing  (19389) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1918
#  10%|▉         | 295/2993 [20:38<3:02:25,  4.06s/it]2025-01-18 18:21:15,158 - INFO - Processing  (207932) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=757
#  10%|▉         | 296/2993 [20:44<3:21:14,  4.48s/it]2025-01-18 18:21:20,616 - INFO - Processing  (206256) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2188
#  10%|▉         | 296/2993 [20:44<3:09:02,  4.21s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 132
#     130 if pd.notna(link) and isinstance(link, str) and link.strip():
#     131     logging.info(f"Processing {drug} ({application_number}) => {link}")
# --> 132     updates = extract_sections(link)
#     133     for update in updates:
#     134         df = pd.DataFrame([update], columns=columns)
#
# Cell In[16], line 60, in extract_sections(url)
#      58 response = session.get(url, headers=headers, timeout=10, allow_redirects=True)
#      59 if response.status_code == 200:
# ---> 60     soup = BeautifulSoup(response.text, 'html.parser')
#      61     # Find the h3 tag containing the drug name and application number
#      62     h3_tags = soup.find_all('h3')
#
# File ~/miniconda3/envs/slices/lib/python3.9/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File ~/miniconda3/envs/slices/lib/python3.9/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File ~/miniconda3/envs/slices/lib/python3.9/site-packages/bs4/builder/_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File ~/miniconda3/envs/slices/lib/python3.9/html/parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File ~/miniconda3/envs/slices/lib/python3.9/html/parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File ~/miniconda3/envs/slices/lib/python3.9/html/parser.py:344, in HTMLParser.parse_starttag(self, i)
#     342     self.handle_startendtag(tag, attrs)
#     343 else:
# --> 344     self.handle_starttag(tag, attrs)
#     345     if tag in self.CDATA_CONTENT_ELEMENTS:
#     346         self.set_cdata_mode(tag)
#
# File ~/miniconda3/envs/slices/lib/python3.9/site-packages/bs4/builder/_htmlparser.py:137, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     135 #print("START", name)
#     136 sourceline, sourcepos = self.getpos()
# --> 137 tag = self.soup.handle_starttag(
#     138     name, None, None, attr_dict, sourceline=sourceline,
#     139     sourcepos=sourcepos
#     140 )
#     141 if tag and tag.is_empty_element and handle_empty_element:
#     142     # Unlike other parsers, html.parser doesn't send separate end tag
#     143     # events for empty-element tags. (It's handled in
#    (...)
#     149     # don't want handle_endtag() to cross off any previous end
#     150     # events for tags of this name.
#     151     self.handle_endtag(name, check_already_closed=False)
#
# File ~/miniconda3/envs/slices/lib/python3.9/site-packages/bs4/__init__.py:749, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     744 if (self.parse_only and len(self.tagStack) <= 1
#     745     and (self.parse_only.text
#     746          or not self.parse_only.search_tag(name, attrs))):
#     747     return None
# --> 749 tag = self.element_classes.get(Tag, Tag)(
#     750     self, self.builder, name, namespace, nsprefix, attrs,
#     751     self.currentTag, self._most_recent_element,
#     752     sourceline=sourceline, sourcepos=sourcepos,
#     753     namespaces=namespaces
#     754 )
#     755 if tag is None:
#     756     return tag
#
# File ~/miniconda3/envs/slices/lib/python3.9/site-packages/bs4/element.py:1314, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1312     self.interesting_string_types = builder.string_containers[self.name]
#    1313 else:
# -> 1314     self.interesting_string_types = self.DEFAULT_INTERESTING_STRING_TYPES
#
# KeyboardInterrupt:

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import logging
import random
import time
from tqdm import tqdm
import os
import re

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Load the input CSV file
input_file_path = '/scratch/harsha.vasamsetti/Drug Safety-related Labeling Changes (SrLC).csv'
drug_data = pd.read_csv(input_file_path)

# Define columns for the output CSV
columns = [
    'Drug', 'Application Number', 'Date', 'Boxed Warning', 'Contraindications',
    'Warnings and Precautions', 'Adverse Reactions', 'Drug Interactions',
    'Use in Specific Populations', 'PCI/PI/MG'
]

# List of User-Agent strings
user_agents = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:89.0) Gecko/20100101 Firefox/89.0',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'
]

# Set up a requests Session
session = requests.Session()

# Common headers for a real browser
base_headers = {
    'User-Agent': random.choice(user_agents),
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Referer': 'https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-User': '?1',
    'Host': 'www.accessdata.fda.gov',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache'
}

def extract_sections(url):
    updates = []
    try:
        headers = base_headers.copy()
        headers['User-Agent'] = random.choice(user_agents)
        response = session.get(url, headers=headers, timeout=10, allow_redirects=True)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            # Find the h3 tag containing the drug name and application number
            h3_tags = soup.find_all('h3')
            drug_name = ''
            app_number = ''
            for h3 in h3_tags:
                if 'NDA-' in h3.get_text() or 'BLA-' in h3.get_text():
                    drug_app_info = h3.get_text(strip=True)
                    logging.debug(f"Drug application info: {drug_app_info}")
                    drug_name = drug_app_info.split(' (')[0].strip()
                    app_number_match = re.search(r'(NDA|BLA)-(\d+)', drug_app_info)
                    if app_number_match:
                        app_number = app_number_match.group(2)
                    break
            # Find all update headers
            update_headers = soup.find_all('h3', class_='background_text accordion-header ui-accordion-header ui-helper-reset ui-state-default ui-accordion-icons ui-corner-all')
            for header in update_headers:
                date_str = header.find(text=True, recursive=False).strip()
                content_div = header.find_next('div', class_='ui-accordion-content ui-helper-reset ui-widget-content ui-corner-bottom')
                if content_div:
                    sections = {
                        'Boxed Warning': '',
                        'Contraindications': '',
                        'Warnings and Precautions': '',
                        'Adverse Reactions': '',
                        'Drug Interactions': '',
                        'Use in Specific Populations': '',
                        'PCI/PI/MG': ''
                    }
                    for h4 in content_div.find_all('h4'):
                        header_text = h4.get_text(strip=True).lower()
                        if 'boxed warning' in header_text:
                            sections['Boxed Warning'] = 'x'
                        elif 'contraindications' in header_text:
                            sections['Contraindications'] = 'x'
                        elif 'warnings and precautions' in header_text:
                            sections['Warnings and Precautions'] = 'x'
                        elif 'adverse reactions' in header_text:
                            sections['Adverse Reactions'] = 'x'
                        elif 'drug interactions' in header_text:
                            sections['Drug Interactions'] = 'x'
                        elif 'use in specific populations' in header_text:
                            sections['Use in Specific Populations'] = 'x'
                        elif 'pci' in header_text or 'patient counseling information' in header_text:
                            sections['PCI/PI/MG'] = 'x'
                    update_data = {
                        'Drug': drug_name,
                        'Application Number': app_number,
                        'Date': date_str,
                        **sections
                    }
                    updates.append(update_data)
        else:
            logging.error(f"Failed to retrieve URL {url}: Status code {response.status_code}")
    except Exception as e:
        logging.error(f"Error processing URL {url}: {e}")
    return updates

# Define the output file path
output_file_path = 'Drug_Safety_Labels_Output1.csv'

# Check if the file exists; if not, write the header
if not os.path.exists(output_file_path):
    pd.DataFrame(columns=columns).to_csv(output_file_path, index=False, encoding='utf-8')

# Process each drug in the input file
for index, row in tqdm(drug_data.iterrows(), total=len(drug_data)):
    drug = row.get('Drug', '')
    application_number = row.get('Application Number', '')
    link = row.get('Link', '')

    if pd.notna(link) and isinstance(link, str) and link.strip():
        logging.info(f"Processing {drug} ({application_number}) => {link}")
        updates = extract_sections(link)
        for update in updates:
            df = pd.DataFrame([update], columns=columns)
            df.to_csv(output_file_path, mode='a', header=False, index=False, encoding='utf-8')
        time.sleep(random.uniform(2, 5))

logging.info(f"Data extraction complete. Output saved to {output_file_path}")
# Out:
#   0%|          | 0/2993 [00:00<?, ?it/s]2025-01-18 18:30:08,322 - INFO - Processing  (21436) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=38
# /tmp/ipykernel_40608/3807666223.py:77: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   date_str = header.find(text=True, recursive=False).strip()
#   0%|          | 1/2993 [00:05<4:37:52,  5.57s/it]2025-01-18 18:30:13,895 - INFO - Processing  (21713) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=39
#   0%|          | 2/2993 [00:08<3:31:57,  4.25s/it]2025-01-18 18:30:17,223 - INFO - Processing  (21729) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=40
#   0%|          | 3/2993 [00:14<3:57:02,  4.76s/it]2025-01-18 18:30:22,580 - INFO - Processing  (21866) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=41
#   0%|          | 4/2993 [00:18<3:38:00,  4.38s/it]2025-01-18 18:30:26,374 - INFO - Processing  (202971) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=24
#   0%|          | 5/2993 [00:22<3:30:49,  4.23s/it]2025-01-18 18:30:30,354 - INFO - Processing  (207202) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=2193
#   0%|          | 6/2993 [00:25<3:23:46,  4.09s/it]2025-01-18 18:30:34,177 - INFO - Processing  (21660) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=1655
#   0%|          | 7/2993 [00:31<3:48:53,  4.60s/it]2025-01-18 18:30:39,816 - INFO - Processing  (761118) => https://www.accessdata.fda.gov/scripts/cder/safetylabelingchanges/index.cfm?event=searchdetail.page&DrugNameID=